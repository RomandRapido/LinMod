# %%
library(tidyverse)
# Out:
# -- Attaching core tidyverse packages ------------------------ tidyverse 2.0.0 --
# v dplyr     1.1.4     v readr     2.1.5
# v forcats   1.0.0     v stringr   1.5.0
# v ggplot2   3.4.2     v tibble    3.2.1
# v lubridate 1.9.3     v tidyr     1.3.1
# v purrr     1.0.2
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()
# i Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
df <- read_csv("Harmful Algae Blooms in Bolinao (from HABhub) - Sheet1.csv")

colnames(df)
# Out:
# Rows: 1929 Columns: 10
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr  (2): station_name, embayment
# dbl  (6): longitude, latitude, dissolved oxygen, ph, water temp, chlorophyll-a
# date (1): sample_date
# time (1): time
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
#  [1] "station_name"     "embayment"        "longitude"        "latitude"
#  [5] "sample_date"      "dissolved oxygen" "ph"               "water temp"
#  [9] "time"             "chlorophyll-a"

# %%
X <- select(df, c("dissolved oxygen", "ph", "water temp"))
model <- lm(df$`chlorophyll-a` ~ ., data = X)

# %%
summary(model)
# Out:
# Call:
# lm(formula = df$`chlorophyll-a` ~ ., data = X)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -7.426 -2.468 -0.981  1.184 34.730
#
# Coefficients:
#                     Estimate Std. Error t value Pr(>|t|)
# (Intercept)        -58.36112    2.98438  -19.56   <2e-16 ***
# `dissolved oxygen`   0.04142    0.03236    1.28    0.201
# ph                   0.82425    0.06173   13.35   <2e-16 ***
# `water temp`         1.91004    0.09303   20.53   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 4.254 on 1925 degrees of freedom
# Multiple R-squared:  0.1996,	Adjusted R-squared:  0.1984
# F-statistic:   160 on 3 and 1925 DF,  p-value: < 2.2e-16

# %%
plot(model)
# Out:
# Plot with title ""
# Plot with title ""
# Plot with title ""
# Plot with title ""
